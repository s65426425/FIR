# %%
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt

# %%
x = np.array( [ 1, 2, 4, 3, 2, 1, 1 ] )
b = np.ones( 3 ) / 3
y = signal.lfilter( b, 1, x )

print( "x =", x )
print( "y =", y )
# Out:
# x = [1 2 4 3 2 1 1]
# y = [0.33333333 1.         2.33333333 3.         3.         2.
#  1.33333333]

# %%
plt.figure(1)                             # 繪圖
plt.plot( x, '--', label = "x" )
plt.plot( y, '-', label = "y" )
plt.xlabel( 't' )
plt.ylabel( 'move average' )
plt.legend(loc = "best")

plt.show()
